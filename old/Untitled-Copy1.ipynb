# %% [markdown]
# # 0.0 Imports

# %%
import pandas as pd
import re
import numpy as np
import seaborn as sns
from warnings import filterwarnings
from category_encoders import TargetEncoder 
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.naive_bayes import GaussianNB
from boruta import BorutaPy
from xgboost import XGBRegressor
from sklearn.neural_network import MLPRegressor
from lightgbm import LGBMRegressor
pd.set_option('display.max_columns', None)
filterwarnings('ignore')

# %%
# se for preciso, colocar mais dados!

# %% [markdown]
# # 1.0 Collect Data

# %%
# Import
pesquisas = pd.read_csv('pesquisas_eleitorais.csv')
resultados = pd.read_csv('resultados_eleicao.csv')
resultados_governador = pd.read_csv('resultados_governador.csv')

# Concat results
resultados['local_que_concorreu']='br'
resultados = pd.concat([resultados,resultados_governador])

# %% [markdown]
# # 2.0 Data Cleaning

# %% [markdown]
# ## 2.1 Filtering Rows

# %%
# Trabalharei com pesquisas/resultados presidenciais de eleições de 2006 até 2002
# Também incluo na análise as pesquisas para governador com pesquisas/resultados de 2018 até 2022

pesquisas = pesquisas[(pesquisas['cargo']=='presidente')&(pesquisas['ano']>=2006)|(pesquisas['cargo']=='governador')&(pesquisas['ano']>=2018)]

# %% [markdown]
# ## 2.2 NaN Values

# %%
pesquisas.isna().sum()
# Out:
# id_pesquisa                   0
# ano                           0
# sigla_uf                  14241
# nome_municipio            40248
# cargo                         0
# data                          0
# data_referencia               0
# instituto                     0
# contratante                8537
# orgao_registro             9551
# numero_registro            9578
# quantidade_entrevistas       72
# margem_mais                   0
# margem_menos                  0
# tipo                        225
# turno                         0
# tipo_voto                     0
# id_cenario                    0
# descricao_cenario             0
# id_candidato_poder360         0
# nome_candidato                0
# sigla_partido             11558
# condicao                      0
# percentual                    0
# dtype: int64

# %% [markdown]
# ### 2.2.1 Tipo do Cenário

# %%
pesquisas[pesquisas['tipo'].isna()]
# Out:
#         id_pesquisa   ano sigla_uf nome_municipio       cargo        data  \
# 29             9225  2019      NaN            NaN  presidente  2019-08-31
# 30             9225  2019      NaN            NaN  presidente  2019-08-31
# 31             9225  2019      NaN            NaN  presidente  2019-08-31
# 32             9225  2019      NaN            NaN  presidente  2019-08-31
# 34759          9270  2019      NaN            NaN  presidente  2019-04-03
# ...             ...   ...      ...            ...         ...         ...
# 109145         9307  2020      NaN            NaN  presidente  2020-06-24
# 109146         9307  2020      NaN            NaN  presidente  2020-06-24
# 109147         9305  2020      NaN            NaN  presidente  2020-06-10
# 109148         9305  2020      NaN            NaN  presidente  2020-06-10
# 109149         9305  2020      NaN            NaN  presidente  2020-06-10
#
#        data_referencia     instituto contratante orgao_registro  \
# 29      28-31.ago.2019         IBPAD         NaN            NaN
# 30      28-31.ago.2019         IBPAD         NaN            NaN
# 31      28-31.ago.2019         IBPAD         NaN            NaN
# 32      28-31.ago.2019         IBPAD         NaN            NaN
# 34759     1-3.abr.2019    Vox Populi          PT            NaN
# ...                ...           ...         ...            ...
# 109145  22-24.jun.2020  DataPoder360         NaN            NaN
# 109146  22-24.jun.2020  DataPoder360         NaN            NaN
# 109147   8-10.jun.2020  DataPoder360         NaN            NaN
# 109148   8-10.jun.2020  DataPoder360         NaN            NaN
# 109149   8-10.jun.2020  DataPoder360         NaN            NaN
#
#        numero_registro  quantidade_entrevistas  margem_mais  margem_menos  \
# 29                 NaN                     NaN          0.0           0.0
# 30                 NaN                     NaN          0.0           0.0
# 31                 NaN                     NaN          0.0           0.0
# 32                 NaN                     NaN          0.0           0.0
# 34759              NaN                  1985.0          2.2           2.2
# ...                ...                     ...          ...           ...
# 109145             NaN                  2500.0          2.0           2.0
# 109146             NaN                  2500.0          2.0           2.0
# 109147             NaN                  2500.0          2.0           2.0
# 109148             NaN                  2500.0          2.0           2.0
# 109149             NaN                  2500.0          2.0           2.0
#
#        tipo  turno     tipo_voto  id_cenario               descricao_cenario  \
# 29      NaN      1  votos totais       23137            avaliação do governo
# 30      NaN      1  votos totais       23137            avaliação do governo
# 31      NaN      1  votos totais       23137            avaliação do governo
# 32      NaN      1  votos totais       23137            avaliação do governo
# 34759   NaN      1  votos totais       23240            avaliação do governo
# ...     ...    ...           ...         ...                             ...
# 109145  NaN      1  votos totais       23293  avaliação do governo Bolsonaro
# 109146  NaN      1  votos totais       23293  avaliação do governo Bolsonaro
# 109147  NaN      1  votos totais       23294  avaliação do governo Bolsonaro
# 109148  NaN      1  votos totais       23294  avaliação do governo Bolsonaro
# 109149  NaN      1  votos totais       23294  avaliação do governo Bolsonaro
#
#         id_candidato_poder360            nome_candidato sigla_partido  \
# 29                       5441              Ruim/Péssimo           NaN
# 30                       5440                 Ótimo/Bom           NaN
# 31                       5437                   Regular           NaN
# 32                       1210  não sabe / não respondeu           NaN
# 34759                    5437                   Regular           NaN
# ...                       ...                       ...           ...
# 109145                   1210  não sabe / não respondeu           NaN
# 109146                   5557                 desaprova           NaN
# 109147                   1210  não sabe / não respondeu           NaN
# 109148                   5557                 desaprova           NaN
# 109149                   5556                    aprova           NaN
#
#         condicao  percentual
# 29             1        35.0
# 30             1        37.0
# 31             1        26.0
# 32             1         2.0
# 34759          1        39.0
# ...          ...         ...
# 109145         1         9.0
# 109146         0        49.0
# 109147         1        10.0
# 109148         0        50.0
# 109149         0        41.0
#
# [225 rows x 24 columns]

# %% [markdown]
# Me parece que essas pesquisas não são eleitorais!

# %%
pesquisas[pesquisas['tipo'].isna()]['descricao_cenario'].unique()
# Out:
# array(['avaliação do governo', 'avaliação de governo',
#        'aprovação do governo', 'avaliação do  governo',
#        'avaliação do governo (trabalho de Bolsonaro)',
#        'avaliação do trabalho de Bolsonaro',
#        'avaliação do governo Bolsonaro'], dtype=object)

# %% [markdown]
# De fato era isso. Vou dropar!

# %%
pesquisas = pesquisas[~pesquisas['tipo'].isna()]

# %% [markdown]
# ### 2.2.2 Município

# %%
print('Número de linhas:',pesquisas.shape[0])
print('Número de linhas com município vazio:',pesquisas[(pesquisas['nome_municipio'].isna())].shape[0])
# Out:
# Número de linhas: 40098
# Número de linhas com município vazio: 40023

# %%
# Vou dropar, pois basicamente é tudo NaN
pesquisas = pesquisas.drop('nome_municipio',1)

# %% [markdown]
# ### 2.2.3 UF

# %%
# UF vazia
pesquisas[(pesquisas['sigla_uf'].isna())]
# Out:
#         id_pesquisa   ano sigla_uf       cargo        data data_referencia  \
# 0              8023  2006      NaN  presidente  2006-09-19    18-19.set.06
# 1              8023  2006      NaN  presidente  2006-09-19    18-19.set.06
# 2              8023  2006      NaN  presidente  2006-09-19    18-19.set.06
# 3              8023  2006      NaN  presidente  2006-09-19    18-19.set.06
# 4              8023  2006      NaN  presidente  2006-09-19    18-19.set.06
# ...             ...   ...      ...         ...         ...             ...
# 149377         3487  2014      NaN  presidente  2014-10-25     25/OUT/2014
# 149378         3487  2014      NaN  presidente  2014-10-25     25/OUT/2014
# 149379         3487  2014      NaN  presidente  2014-10-25     25/OUT/2014
# 149380         3488  2014      NaN  presidente  2014-10-25     25/Oct/2014
# 149381         3488  2014      NaN  presidente  2014-10-25     25/Oct/2014
#
#         instituto                 contratante orgao_registro numero_registro  \
# 0       Datafolha                         NaN            NaN             NaN
# 1       Datafolha                         NaN            NaN             NaN
# 2       Datafolha                         NaN            NaN             NaN
# 3       Datafolha                         NaN            NaN             NaN
# 4       Datafolha                         NaN            NaN             NaN
# ...           ...                         ...            ...             ...
# 149377  Datafolha  Folha de S/ Paulo/TV Globo            TSE  BR- 01210/2014
# 149378  Datafolha  Folha de S/ Paulo/TV Globo            TSE  BR- 01210/2014
# 149379  Datafolha  Folha de S/ Paulo/TV Globo            TSE  BR- 01210/2014
# 149380  Datafolha  Folha de S/ Paulo/TV Globo            TSE  BR- 01210/2014
# 149381  Datafolha  Folha de S/ Paulo/TV Globo            TSE  BR- 01210/2014
#
#         quantidade_entrevistas  margem_mais  margem_menos        tipo  turno  \
# 0                          NaN          2.0           2.0  estimulada      1
# 1                          NaN          2.0           2.0  estimulada      1
# 2                          NaN          2.0           2.0  estimulada      1
# 3                          NaN          2.0           2.0  estimulada      1
# 4                          NaN          2.0           2.0  estimulada      1
# ...                        ...          ...           ...         ...    ...
# 149377                 19318.0          2.0           2.0  estimulada      2
# 149378                 19318.0          2.0           2.0  estimulada      2
# 149379                 19318.0          2.0           2.0  estimulada      2
# 149380                 19318.0          2.0           2.0  estimulada      2
# 149381                 19318.0          2.0           2.0  estimulada      2
#
#            tipo_voto  id_cenario                     descricao_cenario  \
# 0       votos totais       20265            cenário único - estimulado
# 1       votos totais       20265            cenário único - estimulado
# 2       votos totais       20265            cenário único - estimulado
# 3       votos totais       20265            cenário único - estimulado
# 4       votos totais       20265            cenário único - estimulado
# ...              ...         ...                                   ...
# 149377  votos totais        8594                   Diversos candidatos
# 149378  votos totais        8594                   Diversos candidatos
# 149379  votos totais        8594                   Diversos candidatos
# 149380  votos totais        8595  Diversos candidatos (votos válidos)
# 149381  votos totais        8595  Diversos candidatos (votos válidos)
#
#         id_candidato_poder360                            nome_candidato  \
# 0                        1508                         Rui Costa Pimenta
# 1                         938                             Luciano Bivar
# 2                         327                         Cristovam Buarque
# 3                         645                            Heloísa Helena
# 4                         806                                    Eymael
# ...                       ...                                       ...
# 149377                    176                               Aécio Neves
# 149378                    214  branco / nulo / não sabe / não respondeu
# 149379                    361                            Dilma Rousseff
# 149380                    176                               Aécio Neves
# 149381                    361                            Dilma Rousseff
#
#        sigla_partido  condicao  percentual
# 0                PCO         0         0.0
# 1                PSL         0         0.0
# 2                PDT         0         2.0
# 3               Psol         0         9.0
# 4               PSDC         0         0.0
# ...              ...       ...         ...
# 149377          PSDB         0        43.0
# 149378           NaN         1        10.0
# 149379            PT         0        47.0
# 149380          PSDB         0        48.0
# 149381            PT         0        52.0
#
# [14016 rows x 23 columns]

# %%
# Por agora vou dropar, mas posso rever depois (dada a grande quantidade de NaN)
pesquisas = pesquisas.drop('sigla_uf',1)

# %% [markdown]
# ### 2.2.4 Contratante

# %%
pesquisas[pesquisas['contratante'].isna()]
# Out:
#         id_pesquisa   ano       cargo        data data_referencia  \
# 0              8023  2006  presidente  2006-09-19    18-19.set.06
# 1              8023  2006  presidente  2006-09-19    18-19.set.06
# 2              8023  2006  presidente  2006-09-19    18-19.set.06
# 3              8023  2006  presidente  2006-09-19    18-19.set.06
# 4              8023  2006  presidente  2006-09-19    18-19.set.06
# ...             ...   ...         ...         ...             ...
# 148787         7633  2018  presidente  2017-09-04    1-4.set.2017
# 148788         7633  2018  presidente  2017-09-04    1-4.set.2017
# 148789         7633  2018  presidente  2017-09-04    1-4.set.2017
# 148790         7633  2018  presidente  2017-09-04    1-4.set.2017
# 148791         7633  2018  presidente  2017-09-04    1-4.set.2017
#
#               instituto contratante orgao_registro numero_registro  \
# 0             Datafolha         NaN            NaN             NaN
# 1             Datafolha         NaN            NaN             NaN
# 2             Datafolha         NaN            NaN             NaN
# 3             Datafolha         NaN            NaN             NaN
# 4             Datafolha         NaN            NaN             NaN
# ...                 ...         ...            ...             ...
# 148787  Instituto Falpe         NaN            NaN             NaN
# 148788  Instituto Falpe         NaN            NaN             NaN
# 148789  Instituto Falpe         NaN            NaN             NaN
# 148790  Instituto Falpe         NaN            NaN             NaN
# 148791  Instituto Falpe         NaN            NaN             NaN
#
#         quantidade_entrevistas  margem_mais  margem_menos        tipo  turno  \
# 0                          NaN          2.0           2.0  estimulada      1
# 1                          NaN          2.0           2.0  estimulada      1
# 2                          NaN          2.0           2.0  estimulada      1
# 3                          NaN          2.0           2.0  estimulada      1
# 4                          NaN          2.0           2.0  estimulada      1
# ...                        ...          ...           ...         ...    ...
# 148787                  1534.0          3.0           3.0  estimulada      1
# 148788                  1534.0          3.0           3.0  estimulada      1
# 148789                  1534.0          3.0           3.0  estimulada      1
# 148790                  1534.0          3.0           3.0  estimulada      1
# 148791                  1534.0          3.0           3.0  estimulada      1
#
#            tipo_voto  id_cenario           descricao_cenario  \
# 0       votos totais       20265  cenário único - estimulado
# 1       votos totais       20265  cenário único - estimulado
# 2       votos totais       20265  cenário único - estimulado
# 3       votos totais       20265  cenário único - estimulado
# 4       votos totais       20265  cenário único - estimulado
# ...              ...         ...                         ...
# 148787  votos totais       18909          cenário estimulado
# 148788  votos totais       18909          cenário estimulado
# 148789  votos totais       18909          cenário estimulado
# 148790  votos totais       18909          cenário estimulado
# 148791  votos totais       18909          cenário estimulado
#
#         id_candidato_poder360                       nome_candidato  \
# 0                        1508                    Rui Costa Pimenta
# 1                         938                        Luciano Bivar
# 2                         327                    Cristovam Buarque
# 3                         645                       Heloísa Helena
# 4                         806                               Eymael
# ...                       ...                                  ...
# 148787                    855                           João Doria
# 148788                    973                                 Lula
# 148789                    678  indeciso / não sabe / não respondeu
# 148790                    575                              Alckmin
# 148791                    209                        branco / nulo
#
#        sigla_partido  condicao  percentual
# 0                PCO         0         0.0
# 1                PSL         0         0.0
# 2                PDT         0         2.0
# 3               Psol         0         9.0
# 4               PSDC         0         0.0
# ...              ...       ...         ...
# 148787          PSDB         0         1.5
# 148788            PT         0        51.5
# 148789           NaN         1        16.0
# 148790          PSDB         0         2.0
# 148791           NaN         1        19.0
#
# [8460 rows x 22 columns]

# %%
# Vou imputar um valor por enquanto
pesquisas['contratante'] = pesquisas['contratante'].fillna('Sem dados')

# %% [markdown]
# ### 2.2.5 Órgão e Número de Registro

# %%
# Ambos vazios
pesquisas[(pesquisas['orgao_registro'].isna())&(pesquisas['numero_registro'].isna())]
# Out:
#         id_pesquisa   ano       cargo        data data_referencia  \
# 0              8023  2006  presidente  2006-09-19    18-19.set.06
# 1              8023  2006  presidente  2006-09-19    18-19.set.06
# 2              8023  2006  presidente  2006-09-19    18-19.set.06
# 3              8023  2006  presidente  2006-09-19    18-19.set.06
# 4              8023  2006  presidente  2006-09-19    18-19.set.06
# ...             ...   ...         ...         ...             ...
# 148787         7633  2018  presidente  2017-09-04    1-4.set.2017
# 148788         7633  2018  presidente  2017-09-04    1-4.set.2017
# 148789         7633  2018  presidente  2017-09-04    1-4.set.2017
# 148790         7633  2018  presidente  2017-09-04    1-4.set.2017
# 148791         7633  2018  presidente  2017-09-04    1-4.set.2017
#
#               instituto contratante orgao_registro numero_registro  \
# 0             Datafolha   Sem dados            NaN             NaN
# 1             Datafolha   Sem dados            NaN             NaN
# 2             Datafolha   Sem dados            NaN             NaN
# 3             Datafolha   Sem dados            NaN             NaN
# 4             Datafolha   Sem dados            NaN             NaN
# ...                 ...         ...            ...             ...
# 148787  Instituto Falpe   Sem dados            NaN             NaN
# 148788  Instituto Falpe   Sem dados            NaN             NaN
# 148789  Instituto Falpe   Sem dados            NaN             NaN
# 148790  Instituto Falpe   Sem dados            NaN             NaN
# 148791  Instituto Falpe   Sem dados            NaN             NaN
#
#         quantidade_entrevistas  margem_mais  margem_menos        tipo  turno  \
# 0                          NaN          2.0           2.0  estimulada      1
# 1                          NaN          2.0           2.0  estimulada      1
# 2                          NaN          2.0           2.0  estimulada      1
# 3                          NaN          2.0           2.0  estimulada      1
# 4                          NaN          2.0           2.0  estimulada      1
# ...                        ...          ...           ...         ...    ...
# 148787                  1534.0          3.0           3.0  estimulada      1
# 148788                  1534.0          3.0           3.0  estimulada      1
# 148789                  1534.0          3.0           3.0  estimulada      1
# 148790                  1534.0          3.0           3.0  estimulada      1
# 148791                  1534.0          3.0           3.0  estimulada      1
#
#            tipo_voto  id_cenario           descricao_cenario  \
# 0       votos totais       20265  cenário único - estimulado
# 1       votos totais       20265  cenário único - estimulado
# 2       votos totais       20265  cenário único - estimulado
# 3       votos totais       20265  cenário único - estimulado
# 4       votos totais       20265  cenário único - estimulado
# ...              ...         ...                         ...
# 148787  votos totais       18909          cenário estimulado
# 148788  votos totais       18909          cenário estimulado
# 148789  votos totais       18909          cenário estimulado
# 148790  votos totais       18909          cenário estimulado
# 148791  votos totais       18909          cenário estimulado
#
#         id_candidato_poder360                       nome_candidato  \
# 0                        1508                    Rui Costa Pimenta
# 1                         938                        Luciano Bivar
# 2                         327                    Cristovam Buarque
# 3                         645                       Heloísa Helena
# 4                         806                               Eymael
# ...                       ...                                  ...
# 148787                    855                           João Doria
# 148788                    973                                 Lula
# 148789                    678  indeciso / não sabe / não respondeu
# 148790                    575                              Alckmin
# 148791                    209                        branco / nulo
#
#        sigla_partido  condicao  percentual
# 0                PCO         0         0.0
# 1                PSL         0         0.0
# 2                PDT         0         2.0
# 3               Psol         0         9.0
# 4               PSDC         0         0.0
# ...              ...       ...         ...
# 148787          PSDB         0         1.5
# 148788            PT         0        51.5
# 148789           NaN         1        16.0
# 148790          PSDB         0         2.0
# 148791           NaN         1        19.0
#
# [9326 rows x 22 columns]

# %%
# Com número, mas sem órgão
pesquisas[(pesquisas['orgao_registro'].isna())&(pesquisas['numero_registro'].notna())]
# Out:
# Empty DataFrame
# Columns: [id_pesquisa, ano, cargo, data, data_referencia, instituto, contratante, orgao_registro, numero_registro, quantidade_entrevistas, margem_mais, margem_menos, tipo, turno, tipo_voto, id_cenario, descricao_cenario, id_candidato_poder360, nome_candidato, sigla_partido, condicao, percentual]
# Index: []

# %%
# Sem número, mas com órgão
pesquisas[(pesquisas['orgao_registro'].notna())&(pesquisas['numero_registro'].isna())]
# Out:
#        id_pesquisa   ano       cargo        data data_referencia  \
# 89668         9726  2022  presidente  2021-06-10   7-10.jun.2021
# 89669         9726  2022  presidente  2021-06-10   7-10.jun.2021
# 89670         9726  2022  presidente  2021-06-10   7-10.jun.2021
# 89671         9726  2022  presidente  2021-06-10   7-10.jun.2021
# 89672         9726  2022  presidente  2021-06-10   7-10.jun.2021
# 89673         9726  2022  presidente  2021-06-10   7-10.jun.2021
# 89674         9726  2022  presidente  2021-06-10   7-10.jun.2021
# 89675         9726  2022  presidente  2021-06-10   7-10.jun.2021
# 89676         9726  2022  presidente  2021-06-10   7-10.jun.2021
# 89677         9726  2022  presidente  2021-06-10   7-10.jun.2021
# 89678         9726  2022  presidente  2021-06-10   7-10.jun.2021
# 89679         9726  2022  presidente  2021-06-10   7-10.jun.2021
# 89680         9726  2022  presidente  2021-06-10   7-10.jun.2021
# 89681         9726  2022  presidente  2021-06-10   7-10.jun.2021
# 89682         9726  2022  presidente  2021-06-10   7-10.jun.2021
# 89683         9726  2022  presidente  2021-06-10   7-10.jun.2021
# 89684         9726  2022  presidente  2021-06-10   7-10.jun.2021
# 89685         9726  2022  presidente  2021-06-10   7-10.jun.2021
# 89686         9726  2022  presidente  2021-06-10   7-10.jun.2021
# 89687         9726  2022  presidente  2021-06-10   7-10.jun.2021
# 89688         9726  2022  presidente  2021-06-10   7-10.jun.2021
# 89689         9726  2022  presidente  2021-06-10   7-10.jun.2021
# 89690         9726  2022  presidente  2021-06-10   7-10.jun.2021
# 89691         9726  2022  presidente  2021-06-10   7-10.jun.2021
# 89692         9726  2022  presidente  2021-06-10   7-10.jun.2021
# 89693         9726  2022  presidente  2021-06-10   7-10.jun.2021
# 89694         9726  2022  presidente  2021-06-10   7-10.jun.2021
#
#               instituto contratante               orgao_registro  \
# 89668  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
# 89669  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
# 89670  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
# 89671  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
# 89672  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
# 89673  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
# 89674  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
# 89675  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
# 89676  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
# 89677  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
# 89678  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
# 89679  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
# 89680  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
# 89681  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
# 89682  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
# 89683  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
# 89684  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
# 89685  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
# 89686  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
# 89687  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
# 89688  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
# 89689  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
# 89690  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
# 89691  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
# 89692  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
# 89693  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
# 89694  Paraná Pesquisas   Sem dados  Tribunal Superior Eleitoral
#
#       numero_registro  quantidade_entrevistas  margem_mais  margem_menos  \
# 89668             NaN                  1818.0          2.5           2.5
# 89669             NaN                  1818.0          2.5           2.5
# 89670             NaN                  1818.0          2.5           2.5
# 89671             NaN                  1818.0          2.5           2.5
# 89672             NaN                  1818.0          2.5           2.5
# 89673             NaN                  1818.0          2.5           2.5
# 89674             NaN                  1818.0          2.5           2.5
# 89675             NaN                  1818.0          2.5           2.5
# 89676             NaN                  1818.0          2.5           2.5
# 89677             NaN                  1818.0          2.5           2.5
# 89678             NaN                  1818.0          2.5           2.5
# 89679             NaN                  1818.0          2.5           2.5
# 89680             NaN                  1818.0          2.5           2.5
# 89681             NaN                  1818.0          2.5           2.5
# 89682             NaN                  1818.0          2.5           2.5
# 89683             NaN                  1818.0          2.5           2.5
# 89684             NaN                  1818.0          2.5           2.5
# 89685             NaN                  1818.0          2.5           2.5
# 89686             NaN                  1818.0          2.5           2.5
# 89687             NaN                  1818.0          2.5           2.5
# 89688             NaN                  1818.0          2.5           2.5
# 89689             NaN                  1818.0          2.5           2.5
# 89690             NaN                  1818.0          2.5           2.5
# 89691             NaN                  1818.0          2.5           2.5
# 89692             NaN                  1818.0          2.5           2.5
# 89693             NaN                  1818.0          2.5           2.5
# 89694             NaN                  1818.0          2.5           2.5
#
#              tipo  turno     tipo_voto  id_cenario  \
# 89668  estimulada      1  votos totais       24401
# 89669  estimulada      1  votos totais       24401
# 89670  estimulada      1  votos totais       24401
# 89671  estimulada      1  votos totais       24401
# 89672  estimulada      1  votos totais       24401
# 89673  estimulada      1  votos totais       24401
# 89674  estimulada      1  votos totais       24401
# 89675  estimulada      1  votos totais       24401
# 89676  estimulada      1  votos totais       24401
# 89677  estimulada      1  votos totais       24401
# 89678  estimulada      1  votos totais       24402
# 89679  estimulada      1  votos totais       24402
# 89680  estimulada      1  votos totais       24402
# 89681  estimulada      1  votos totais       24402
# 89682  estimulada      1  votos totais       24402
# 89683  estimulada      2  votos totais       24403
# 89684  estimulada      2  votos totais       24403
# 89685  estimulada      2  votos totais       24403
# 89686  estimulada      2  votos totais       24403
# 89687  estimulada      2  votos totais       24404
# 89688  estimulada      2  votos totais       24404
# 89689  estimulada      2  votos totais       24404
# 89690  estimulada      2  votos totais       24404
# 89691  estimulada      2  votos totais       24405
# 89692  estimulada      2  votos totais       24405
# 89693  estimulada      2  votos totais       24405
# 89694  estimulada      2  votos totais       24405
#
#                        descricao_cenario  id_candidato_poder360  \
# 89668  cenário 1 - estimulado - 1º turno                    706
# 89669  cenário 1 - estimulado - 1º turno                   4982
# 89670  cenário 1 - estimulado - 1º turno                    855
# 89671  cenário 1 - estimulado - 1º turno                    973
# 89672  cenário 1 - estimulado - 1º turno                    841
# 89673  cenário 1 - estimulado - 1º turno                   3438
# 89674  cenário 1 - estimulado - 1º turno                    289
# 89675  cenário 1 - estimulado - 1º turno                   1210
# 89676  cenário 1 - estimulado - 1º turno                   1563
# 89677  cenário 1 - estimulado - 1º turno                   3152
# 89678  cenário 2 - estimulado - 1º turno                    706
# 89679  cenário 2 - estimulado - 1º turno                   4982
# 89680  cenário 2 - estimulado - 1º turno                   3152
# 89681  cenário 2 - estimulado - 1º turno                    973
# 89682  cenário 2 - estimulado - 1º turno                   1210
# 89683  cenário 1 - estimulado - 2º turno                   1210
# 89684  cenário 1 - estimulado - 2º turno                   4982
# 89685  cenário 1 - estimulado - 2º turno                    706
# 89686  cenário 1 - estimulado - 2º turno                   3152
# 89687  cenário 2 - estimulado - 2º turno                   4982
# 89688  cenário 2 - estimulado - 2º turno                    973
# 89689  cenário 2 - estimulado - 2º turno                   1210
# 89690  cenário 2 - estimulado - 2º turno                   3152
# 89691  cenário 3 - estimulado - 2º turno                    973
# 89692  cenário 3 - estimulado - 2º turno                   4982
# 89693  cenário 3 - estimulado - 2º turno                    706
# 89694  cenário 3 - estimulado - 2º turno                   1210
#
#                  nome_candidato sigla_partido  condicao  percentual
# 89668                 Bolsonaro   sem partido         0        34.0
# 89669    branco / nulo / nenhum           NaN         1         7.5
# 89670                João Doria          PSDB         0         5.2
# 89671                      Lula            PT         0        29.3
# 89672               João Amoêdo          Novo         0         4.1
# 89673    Luiz Henrique Mandetta           DEM         0         1.5
# 89674                      Ciro           PDT         0         5.9
# 89675  não sabe / não respondeu           NaN         1         3.4
# 89676              Simone Tebet           MDB         0         0.3
# 89677          José Luiz Datena   sem partido         0         9.0
# 89678                 Bolsonaro   sem partido         0        36.2
# 89679    branco / nulo / nenhum           NaN         1        10.5
# 89680          José Luiz Datena   sem partido         0        15.1
# 89681                      Lula            PT         0        33.9
# 89682  não sabe / não respondeu           NaN         1         4.3
# 89683  não sabe / não respondeu           NaN         1         4.5
# 89684    branco / nulo / nenhum           NaN         1        18.3
# 89685                 Bolsonaro   sem partido         0        39.1
# 89686          José Luiz Datena   sem partido         0        38.2
# 89687    branco / nulo / nenhum           NaN         1        22.2
# 89688                      Lula            PT         0        36.3
# 89689  não sabe / não respondeu           NaN         1         4.8
# 89690          José Luiz Datena   sem partido         0        36.7
# 89691                      Lula            PT         0        37.8
# 89692    branco / nulo / nenhum           NaN         1        16.7
# 89693                 Bolsonaro   sem partido         0        40.3
# 89694  não sabe / não respondeu           NaN         1         5.2

# %%
# Vou dropar o número de registro, pois ele decorre do órgão (não tem número sem órgão)
pesquisas.drop('numero_registro',1,inplace=True)

# Os que tiverem órgão de registro vazios vou imputar um valor arbitrário 
pesquisas['orgao_registro'] = pesquisas['orgao_registro'].fillna('Sem dados')

# %% [markdown]
# ### 2.2.6 Quantidade de Entrevistas

# %%
# Por ser poucos valores, vou a priori imputar com uma medida de tendência central

# %%
# Plot Histogram
sns.histplot(pesquisas['quantidade_entrevistas'])
# Out:
# <AxesSubplot:xlabel='quantidade_entrevistas', ylabel='Count'>

# %%
# Medidas Descritivas
pesquisas['quantidade_entrevistas'].describe()
# Out:
# count    40030.000000
# mean      1929.510867
# std       1730.551133
# min          0.000000
# 25%       1071.000000
# 50%       1640.000000
# 75%       2020.000000
# max      19318.000000
# Name: quantidade_entrevistas, dtype: float64

# %%
# São dado discrepantes. Vou colocar a median por ser mais resistente a outliers: representando melhor essa variavel
pesquisas['quantidade_entrevistas'] = pesquisas['quantidade_entrevistas'].fillna(pesquisas['quantidade_entrevistas'].median())

# %% [markdown]
# ### 2.2.7 Partido

# %%
# Acredito que esse dado será importante para prever.
# Vou deixar NaN, quando tivermos feito nosso dataset final volto se necessário!

# %% [markdown]
# ## 2.3 Inconsistent Data

# %% [markdown]
# ### 2.3.1 Descrição Cenário

# %%
pesquisas['descricao_cenario'].unique()
# Out:
# array(['cenário único - estimulado', 'cenário 1 - espontânea - 1º turno',
#        'cenário 2 - estimulada - 1º turno',
#        'cenário 3 - estimulada - 1º turno',
#        'cenário 4 - estimulada - 1º turno',
#        'cenário 5 - estimulada - 1º turno', 'Diversos candidatos',
#        'Lula vs Serra', 'Lula vs Aécio', 'Lula vs FHC',
#        'Lula vs Alckmin', 'Lula vs Garotinho',
#        'intenção Lula vs Alckmin', 'Dilma vs Aécio', 'Serra vs Genro',
#        'Aécio vs Genro', 'Dilma vs Serra', 'Serra vs Patrus',
#        'Diversos candidatos (votos válidos)',
#        'Dilma vs Aécio (votos válidos)',
#        'cenário 1 - estimulada - 1° turno',
#        'cenário 1 - estimulado - 1º turno',
#        'cenário 1 - espontâneo - 1º turno',
#        'cenário 2 - estimulado - 1º turno',
#        'cenário 3 - estimulado - 1º turno',
#        'cenário 3 - estimulada - 2º turno',
#        'cenário 1 - estimulada - 1º turno',
#        'cenário 2 - espontânea - 1º turno',
#        'cenário 2 - estimulada - 2º turno',
#        'cenário 4 - espontânea - 1º turno',
#        'cenário 1 - estimulada - 2º turno',
#        'cenário 1 - rejeição - estimulada - 1º turno',
#        'cenário 1 - estimulado - 2º turno',
#        'cenário 2 - estimulado - 2º turno',
#        'cenário 3- estimulado - 2º turno',
#        'cenário 4 - estimulada - 2º turno',
#        'cenário 4 - estimulado - 1º turno',
#        'cenário 5 - estimulado - 1º turno',
#        'cenário 6 - estimulado - 1º turno',
#        'cenário 7 - estimulado - 1º turno',
#        'cenário 8 - estimulado - 1º turno',
#        'cenário 3 - estimulado - 2º turno',
#        'cenário 4 - estimulado - 2º turno',
#        'cenário 5 - estimulado - 2º turno',
#        'cenário 6 - estimulado - 2º turno',
#        'cenário 7 - estimulado - 2º turno',
#        'cenário 1 - estimulado - 1ª turno',
#        'cenário 1 - espontâneo - 1ª turno',
#        'cenário 1 - espontâneo - 1° turno',
#        'cenário 1 - estimulado - 1° turno',
#        'cenário 2 - estimulado - 1° turno',
#        'cenário 1 - estimulado - 2° turno',
#        'cenário 2 - estimulado - 2° turno',
#        'cenário 1 - estimualada - 1º turno', 'cenário 1 estimulado',
#        'cenário 2 estimulado', 'cenário 3 estimulado',
#        'cenário 1 - estimulada - rejeição - 1º turno',
#        'cenário 2 - espontâneo - 1ª turno',
#        'cenário 1 - estimulado - 2ª turno',
#        'cenário 2 - estimulado - 2ª turno',
#        'cenário 3 - estimulado - 2ª turno',
#        'cenário 4 - estimulado - 2ª turno',
#        'cenário 5 - estimulado - 2ª turno', 'cenário 1 estimulada',
#        'cenário 1 espontânea', 'cenário estimulado', 'cenário espontâneo',
#        'cenário 2 - estimulada - rejeição - 1º turno',
#        'cenário 1 - estimulado', 'cenário 2 - estimulado',
#        'cenário 3 - estimulado', 'cenário 4 - estimulado',
#        'cenário 4 estimulado', 'Serra vs Ciro', 'Dilma vs Ciro',
#        'cenário 5 estimulado', 'cenário 6 estimulado',
#        'cenário 7 estimulado', 'cenário 1 estimulado - 2º turno',
#        'cenário 2 estimulado - 2º turno',
#        'cenário 3 estimulado - 2º turno',
#        'cenário 4 estimulado - 2º turno',
#        'cenário 5 estimulado - 2º turno',
#        'cenário 6 estimulado - 2º turno',
#        'cenário 7 estimulado - 2º turno',
#        'cenário 8 estimulado - 2º turno',
#        'cenário 8 - estimulado - 2º turno',
#        'cenário 9 - estimulado - 2º turno',
#        'cenário 10 - estimulado - 2º turno',
#        'cenário  1 - estimulado - 1º turno',
#        'cenário  1 - estimulado - 2º turno',
#        'cenário  2 - estimulado - 2º turno',
#        'cenário  3 - estimulado - 2º turno',
#        'cenário  4 - estimulado - 2º turno',
#        'cenário  5 - estimulado - 2º turno',
#        'cenário  6 - estimulado - 2º turno',
#        'cenário  7 - estimulado - 2º turno',
#        'cenário 3 - estimulado - 1ª turno',
#        'cenário 4 - estimulada - 2ª turno',
#        'cenário 5 - estimulada - 2ª turno',
#        'cenário 6 - estimulada - 2ª turno',
#        'cenário 7 - estimulada - 2ª turno',
#        'cenário 1 - espontânea - 1ª turno',
#        'cenário 1 - estimulada - 1ª turno',
#        'cenário 2 - estimulado - 1ª turno',
#        'cenário 4 - estimulado - 1ªturno',
#        'cenário 5 - estimulado - governador',
#        'cenário 6 - estimulado - 1ª turno',
#        'cenário 6 - estimulado - 2ª turno',
#        'cenário 7 - estimulado - 2ª turno',
#        'cenário 4 - estimulado - 1ª turno',
#        'cenário 1 - espontâneo 1 - 1º turno',
#        'cenário 1 - espontânea - 1° turno',
#        'cenário 2 - estimulada - 1° turno',
#        'cenário 3 - estimulada - 1° turno',
#        'cenário 1 - estimulada - 2° turno',
#        'cenário 2 - estimulada - 2° turno',
#        'cenário 3 - estimulada - 2° turno',
#        'cenário 4 - estimulada - 2° turno',
#        'cenário 5 - estimulada - 2º turno',
#        'cenário 6 - estimulada - 2º turno',
#        'cenário 7 - estimulada - 2º turno',
#        'cenário 8 - estimulada - 2º turno',
#        'cenário 9 - estimulada - 2º turno',
#        'cenário 3 - estimulado - 2° turno',
#        'cenário 4 - estimulado - 2° turno',
#        'cenário 5 - estimulado - 2° turno', 'Ciro vs Aécio',
#        'Serra vs Palocci', 'Aécio vs Palocci', 'Dilma vs Marina',
#        'Serra vs Marina', 'Dilma vs Serra (votos válidos)',
#        'cenário 1 estimulado – 2º turno',
#        'cenário 2 estimulado –\xa02º turno', 'cenário 5 - estimulado',
#        'CENÁRIO 1 - ESTIMULADO - 1º TURNO',
#        'CENÁRIO 2 - ESTIMULADO - 1º TURNO',
#        'CENÁRIO 3 - ESTIMULADO - 1º TURNO',
#        'CENÁRIO 4 -  ESTIMULADO - 1º TURNO',
#        'CENÁRIO 5 - ESTIMULADO - 1º TURNO',
#        'cenário 1 - estimulado- 2º turno',
#        'cenário 2  - estimulado - 2º turno',
#        'cenário 1 - estimulada - 2ª turno',
#        'cenário 3 - estimulada - 2ª turno',
#        'cenário - espontâneo - 1º turno',
#        'cenário - estimulado - 1º turno',
#        'cenário 4 - estimulada - 1ª turno',
#        'cenário 1 - rejeição - 1ª turno',
#        'cenário 3 - estimulada - 1ª turno',
#        'cenário 2 - estimulado -  2º turno',
#        'cenário 9 - estimulado - 1º turno',
#        'cenário 6- estimulado - 1º turno',
#        'cenário 3 - estimulado - 1° turno',
#        'cenário 5 - estimulado -  2° turno',
#        'cenário 6 - estimulado - 2° turno',
#        'cenário 7 - estimulado - 2° turno',
#        'cenário 8 - estimulado - 2° turno',
#        'cenário 9 - estimulado - 2° turno',
#        'cenário 6 - estimulada - 1º turno',
#        'cenário 1 - 1º turno - estimulada',
#        'cenário 1 - 2º turno - estimulada',
#        'Cenário 1 - espontâneo - 1º turno', 'Lula vs Alckmin (outubro)',
#        'cenário 6 - estimulado', 'cenário 7 - estimulado',
#        'cenário 2 - estimulado - 2ªturno',
#        'Cenário 1 - estimulado - 2º turno', 'avaliação do governo',
#        'cenário 1 - espontânea', 'Aécio vs Dilma',
#        'cenário 1 estimulada - 1º turno',
#        'cenário 2 estimulado - 1º turno',
#        'Cenário 1 - espontânea - 1º turno',
#        'cenário 1 - estimulado - cenário 1',
#        'cenário 4 -estimulado - 1º turno',
#        'cenário 2- estimulado - 2º turno',
#        'cenário 1 -espontâneo - 1º turno',
#        'cenário 1 - estimulada - rejeição - múltipla - 1º turno',
#        'cenário 4 - estimulado - 1° turno',
#        'cenário 2 - estimulada. - 1º turno',
#        'cenário 1 - estimulada - 1º turno - rejeição múltipla',
#        'cenário 1 - estimulada - 1º turno - rejeição',
#        'cenário 1 - estimulada - rejeição múltipla',
#        'cenário 1 - estimulada - 1º turno - votos válidos',
#        'cenário 2- estimulada - 1º turno',
#        'cenário 6 - estimulado - 2ª  turno',
#        'cenário 1 - estimulado - 1ºturno',
#        'cenário estimulado - 2º turno', 'ACM Neto vs Rui Costa',
#        'cenário estimulado 1', 'Diversos Candidatos',
#        'cenário 3 estimulada - 2º turno',
#        'cenário 2 - estimulada - 1º turno - votos válidos',
#        'cenário 1 - estimulada - 2º turno - votos válidos',
#        'Cenário Estimulado 1', 'Cenário Estimulado 2',
#        'cenário 11 - estimulado - 2º turno',
#        'cenário 12 - estimulado - 2º turno',
#        'cenário 13 - estimulado - 2º turno',
#        'cenário 14 - estimulado - 2º turno',
#        'cenário 15 - estimulado - 2º turno',
#        'cenário 16 - estimulado - 2º turno',
#        'cenário 17 - estimulado - 2º turno',
#        'cenário 2 - espontâneo - 1º turno',
#        'cenário 1 - estimulada - rejeição - múltipla',
#        'cenário 5 - estimulado - 1° turno',
#        'cenáro 1 - estimulada - 1º turno',
#        'cenário 2- estimulada - 2º turno',
#        'cenário 1 - estimulada - 1ºturno',
#        'cenário 5 - estimulada - 2° turno',
#        'cenário 2 estimulado – 2º turno',
#        'cenário 1  - espontâneo - 1° turno',
#        'cenário estimulado - 1º turno', 'cenário espontâneo - 1º turno',
#        'rejeição'], dtype=object)

# %%
# Os cenários que não existiram no segundo turno irão sumir quando fizermos nosso dataset final

# %%
# Remove avaliação do governo!
pesquisas = pesquisas[~pesquisas['descricao_cenario'].str.contains('avali')]

# %% [markdown]
# ### 2.3.2 Tipo do cenário

# %%
pesquisas['tipo'].unique()
# Out:
# array(['estimulada', 'espontânea', 'rejeição'], dtype=object)

# %%
# Não quero de rejeição
pesquisas = pesquisas[~pesquisas['tipo'].str.contains('rejei')]

# %% [markdown]
# ### 2.3.3 Conferir conferência entre tipo_voto e desc_cenário

# %%
# Verificar se os que tem entre parênteses "votos válidos" estão com o tipo do voto correto

# %%
pesquisas[pesquisas['descricao_cenario'].str.contains('votos')]['tipo_voto'].unique()
# Out:
# array(['votos totais', 'votos válidos'], dtype=object)

# %% [markdown]
# Vemos aqui que não! Temos que corrigir

# %%
index = pesquisas[pesquisas['descricao_cenario'].str.contains('votos')].index
pesquisas.loc[index,'tipo_voto'] = 'votos válidos'

# %% [markdown]
# ### 2.3.4 Órgão Regulador

# %%
# Quero ver se os nomes são únicos ou se há variação nos nomes
pesquisas['orgao_registro'].unique()
# Out:
# array(['Sem dados', 'TSE', 'TRE/MT', 'TRE', 'TRE-SP', 'TRE-ES', 'TRE-AL',
#        'TRE-PE', '40ª Zona Eleitoral de Betim', 'TRE-MG', 'TRE-RJ',
#        'TRE-RS', 'TRE-BA', 'TRE-DF', 'TRE-AC', 'TRE-MA',
#        'Tribunal Superior Eleitoral', 'TRE-PI', 'TRE-RR', 'TRE-SC',
#        'TRE-TO', 'TRE-GO', 'TRE-PR', 'TRE-CE', 'TRE-MS', 'TRE-RN',
#        'TRE-AM', 'TRE-MT', 'TRE-PB', 'TRE/RN', 'TRE-PA', 'TRE-AP',
#        'TRE-SE', 'TRE-RO', 'TRE/SC', 'TRE/MS', 'TRE - SC', 'n.d'],
#       dtype=object)

# %%
index = pesquisas[pesquisas['orgao_registro'].str.contains('Tribunal Superior')].index
pesquisas.loc[index,'orgao_registro'] = 'TSE'
index = pesquisas[pesquisas['orgao_registro'].str.contains('n.d')].index
pesquisas.loc[index,'orgao_registro'] = 'Sem dados'

# %% [markdown]
# ### 2.3.5 Contratante

# %%
# Quero ver se os nomes são únicos ou se há variação nos nomes
pesquisas['contratante'].unique()
# Out:
# array(['Sem dados', 'Percent Brasil',
#        'Rádio e Televisão Bandeirantes Ltda', 'TV Globo',
#        'Rádio e Televisão Bandeirantes', 'A Gazeta', 'TV Bandeirantes',
#        'Rádio e Televisão Bandeirantes e IG',
#        'O & P Brasil Opinião Análise e Estratégia', 'Jornal Opção',
#        'Fortiori', 'TV Atalaia', 'Jornal da Cidade', 'Sul21', 'TV Gazeta',
#        'Record TV', 'Gazeta de São Paulo', 'Banco Modal', 'TV Mirante',
#        'TV Rádio Clube de Teresina', 'Grupo Globo', 'NC Comunicações',
#        'Centro Norte Comunicação', 'Centro Norte de Comunicação',
#        'Gazeta', 'Folha de S. Paulo e Grupo Globo',
#        'O Povo/ Folha de S/ Paulo', 'Rede Gazeta', 'Gerp', 'A Tarde',
#        'Arko Advice', 'Genial Investimentos', 'Grupo RBS',
#        'Folha de S/ Paulo', 'Folha de S.Paulo', 'O Popular',
#        'Jornal do Tocantins', 'ACIEG', 'Grupo Jaime Câmara',
#        'J. Camara & Irmãos', 'Folha de S. Paulo', 'Folha da Manhã',
#        'Diretório Estadual do União Brasil - PI', 'TV Band Paraná',
#        'Band Natal', 'Veritá', 'jornal Correio do Estado',
#        'Partido Liberal', 'Paraná Pesquisas', 'Jovem Pan', 'Band Paraná',
#        'Televisão Bandeirantes do Paraná', 'Nri Serviços',
#        'Bahia Notícias', 'Editora Cearacom', 'FIEMS',
#        'Diário de S. Paulo', 'Multi Mercado', 'Jornal Hoje em Dia',
#        'Radar', 'Jornal A Gazeta',
#        'Soares Marketing e Pesquisas de Mercado Ltda/', 'Diário de Goiás',
#        'MDB-AL', 'Cada Minuto', 'Diário da Manhã',
#        'Folha de S/ Paulo/TV Globo', 'Televisão Verdes Mares',
#        'Princesa Comunicação', 'Correio Braziliense', 'A Tribuna',
#        'Blog do BG', 'Ipespe', 'Carta Capital', 'No Minuto',
#        'Folha de S.Paulo e Sociedade Rádio Emissora Paranaense',
#        'Folha de S..Paulo', 'Folha de S.Paulo e Rede Globo',
#        'Díario da Manhã', 'TV Record', 'Brasil 247', 'Folha de S/Paulo',
#        'ACIAG', 'TV Globo/ O Estado de S. Paulo', 'Folha de Sao Paulo',
#        'Rádio Campina FM', 'CUT',
#        'Jornal Em Tempo (Terra, editora, comércio e recursos gráficos)',
#        'Amazonas em Tempo (Terra, editora, comércio e recursos gráficos)',
#        'PSDB', 'Gráfica Escolar S.A.', 'Perspectiva (D.M. Duarte)',
#        'O Jornal', 'PDT', 'Leia-se', 'PMDB', 'Walter Gualberto da Silva',
#        'TV Timon', 'TV Serra Dourada', 'Recursos próprios',
#        'Flex Consult', 'A Crítica', 'XP Investimentos', 'Exame',
#        'XP Inc.', 'Blog do Magno', 'Portal da Capital', '6Sigma', 'Opus',
#        'TV Cidade de Fortaleza', 'Folha de S. Paulo  e Grupo Globo',
#        'CNT',
#        'Sindicato dos Trabalhadores nas Indústrias da Construção Pesada e Afins do Estado de São Paulo',
#        'Confederação Nacional dos Transportes',
#        'Farah & Farah Advogados Associados', 'PMDB-AL',
#        'CNT (Confederação Nacional dos Transportes)', 'CadaMinuto Press',
#        'Isto É', 'Sensus', 'IstoÉ', 'Rede Record', 'Diário de Pernambuco',
#        'Prêmio lideres de mercado', 'Recursos Próprios',
#        'Cordeiro Filho Consultoria', 'Rede HG', 'Revista Veja', 'Veja',
#        'Modalmais', 'JET Radiodifusão', 'Mirante TV', 'BTG Pactual',
#        'Asserj', 'Portal de Notícias Agora RN', 'RD Produtora', 'Época',
#        'TV Verdes Mares *Boca de urna', 'jornal O Popular',
#        'Faet (Federação da Agricultura e Pecuária do Estado do Tocantins)',
#        'Associação Comercial de São Paulo (Diário do Comércio)',
#        'CNI (Confederação Nacional da Indústria)',
#        'TV Globo e O Estado de S. Paulo',
#        'O Estado de S.Paulo e Rede Globo', 'Televisão Bahia', 'Ibope',
#        'Estado de Sao Paulo/O Globo', 'União dos Vereadores de SP', 'CNI',
#        'Jornal Estado de Minas', 'TV Globo/Estado de S. Paulo',
#        'CNT (Confederação Nacional do Transporte)',
#        'Confederação Nacional do Transporte', 'Mentor Inteligência',
#        'Doxa', 'jornal O Estado (Rede Independente de Jornal Ltda)',
#        'Folha de S. Paulo e TV Globo', 'PoderData',
#        'Sistema Clube de Comunicação', 'Televisão Centro América',
#        'Federação das Indústrias do Estado do Amazonas',
#        'Sinduscon-TO (Sindicato da Indústria da Construção Civil do Estado do Tocantins)',
#        'Sinduscom (Sindicato da Indústria da Construção Civil da Grande Florianópolis)',
#        'Sinduscon-TO (Sindicato da Industria da Construção Civil do Estado do Tocantins)',
#        'Televisão Morena', 'Televisão Cabugi', 'Rádio TV do Amazonas',
#        'TV Anhanguera', 'TV Liberal', 'Rádio Televisão do Sergipe',
#        'TV Gazeta de Alagoas', 'Revista Exame', 'Rádio 96FM',
#        'TV Anhanguer a', 'TV Morena', 'TV Sergipe', 'TV Rádio Clube',
#        'TV Cabo Branco', 'Centro Norte de comunicação', 'TV Clube',
#        'TV do Amazonas', 'TV Cabugi', 'TV de Sergipe',
#        'PERCENT PESQUISA DE MERCADO E OPINIAO LTDA', 'Percent Brasl',
#        'BGC Liquidez', 'Leia Já', 'Folha de Sao Paulo/TV Globo',
#        'Tiomon FM (Associação para desenvolvimento esportivo, social e cultural - Adesc)',
#        'PT-MG', 'PR-MG', 'Campanha de Teo Vilela',
#        'Câmara dos Dirigentes Logistas de Manaus',
#        'Perspectiva Tecnolgia da Informação',
#        'Perspectiva Tecnologia da Informação', 'Correio da Paraíba',
#        'PT Diretório Regional Acre', 'Jornal Atos', 'TV João Pessoa',
#        'Jornal da Paraíba', 'Rádio Metrópole', 'Rádio Itatiaia',
#        'GERP EMPRESA BRASILEIRA DE PESQUISA', 'Real Time',
#        'BANCO GENIAL S.A.', 'IG', 'O Dia', 'Instituto Ranking',
#        'Novus Mídia', 'MGS News', 'MSG News', 'Perspectiva', 'ADDC',
#        'Agência Jakarta', 'televisão Pioneira Ltda.',
#        'Folha de S.Paulo e TV Globo', 'Anunciação', 'Gazeta de Alagoas',
#        'O Povo', 'TV CaboBranco', 'Sociedade Rádio Emissora Paranaense',
#        'Diário do Nordeste', 'RPC TV', 'Rádio Paranaense', 'Famasul',
#        'Grupo RIC', 'Rio Indústria', 'RBS Participações', 'TV Bahia',
#        'Brada', 'Badra Comunicação', 'TV Globo/Folha de S. Paulo',
#        'Estado de S.Paulo e Rede Globo',
#        'TV Globo/ O Estado de Sao Paulo',
#        'TV Globo/ O Estado de S/ Paulo', 'Maurício de Nassau',
#        'Sindicato das empresas de serviços contábeis', 'IBPS',
#        'Política Alagoana LTDA', '7 Segundos',
#        'Nassau Editora Rádio e Televisão Ltda', 'Multi TV Comunicações',
#        'Portal THN1', 'Rádio Difusora', 'Jornal Folha de S.Paulo',
#        'TV Globo/O Estado de Sao Paulo', 'UNIGRAF', 'TV Pajuçara',
#        'NSTITUTO PARANA DE PESQUISAS E ANALISE DE CONSUMIDOR LTDA',
#        'Campanha de Indio da Costa (DEM)', 'Fundação Ulisses Guimarães',
#        'Folha de S. Paulo e Rede Globo', 'TV Globo/Folha de Sao Paulo',
#        'Portal AZ', 'Band Nordeste', 'Editora Ana Cassia',
#        'Tv Cidade Verde', 'jornal Cinform', 'Coagro', 'TV Antena',
#        'Jales', 'Folha de S.Paulo (Empresa Folha da Manhã S/A)',
#        'Rádio Cidade', 'Instituto Inope', 'Editora Gazeta do Paraná',
#        'TV Paçajura', 'O Liberal', 'Século Diário', 'Cen Comercial Ltda',
#        'Metrópoles', 'CNN Brasil', 'TV Girassol', 'Banco Genial',
#        'BDC Comunicações', 'RPC', 'TV Verdes Mares',
#        'Simplex Consultoria',
#        'Federação das Câmaras de Dirigentes Logistas do Estado do Tocantins',
#        'Fan FM', 'Fieac (Federação das Indústrias do Estado do Acre)',
#        'Band News', 'Editora 180 graus e Jales',
#        'Associação Comercial e Industrial de Campo Grande',
#        'Grupo Folha e TV Globo', 'Ramos Publicidade e Propaganda',
#        'Gazeta do Povo', 'DEM', 'Instituto Mais',
#        'GERP EMPRESA BRASILEIRA DE PESQUISA LTDA',
#        'Federação das Câmaras de Dirigentes Lojistas do Estado da Paraíba',
#        'Frente Favela Brasil', 'Istoé', 'Grupom',
#        'Diretório Estadual do PP (Partido Progressista)',
#        'Certus/Ilumin ar Som e Luz', 'Teresina FM', 'França de Pesquisas',
#        'O Imparcial', 'Certus e Iluminar Som', 'TV GUARA'], dtype=object)

# %%
# Há bastante variação, talvez valha a pena parar um pouco aqui.

# %% [markdown]
# ## 2.4 Drop Irrelevant Columns

# %%
# Cargo é cte, data_referencia não é a data da pesquisa e nome do candidato já tem id
pesquisas.drop(['data_referencia','nome_candidato'],1,inplace=True)

# %% [markdown]
# ## 2.4 Data Dtypes

# %%
pesquisas.dtypes
# Out:
# id_pesquisa                 int64
# ano                         int64
# cargo                      object
# data                       object
# instituto                  object
# contratante                object
# orgao_registro             object
# quantidade_entrevistas    float64
# margem_mais               float64
# margem_menos              float64
# tipo                       object
# turno                       int64
# tipo_voto                  object
# id_cenario                  int64
# descricao_cenario          object
# id_candidato_poder360       int64
# sigla_partido              object
# condicao                    int64
# percentual                float64
# dtype: object

# %%
pesquisas['data'] = pd.to_datetime(pesquisas['data'])

# %%
resultados.dtypes
# Out:
# nome                    object
# partido                 object
# votos                  float64
# votos_validos          float64
# total_votos            float64
# turno                    int64
# ano                      int64
# id_poder_360             int64
# local_que_concorreu     object
# dtype: object

# %% [markdown]
# # 3.0 Feature Engineering

# %%
# Local e Órgão de Registro 

pesquisas['local_registro'] = pesquisas['orgao_registro'].map({'Sem dados':'Sem dados', 'TSE':'Esfera Federal', 'TRE':'Esfera Estadual', 
        'TRE-SP':'SP', 'TRE-AL':'AL', 'TRE-PE':'PE','TRE/MT':'MG','TRE/RN':'RN','TRE/SC':'SC','TRE/MS':'MS',
       '40ª Zona Eleitoral de Betim':'MG', 'TRE-MG':'MG', 'TRE-RJ':'RJ', 'TRE-ES':'ES',
       'TRE-RS':'RS', 'TRE-BA':'BA', 'TRE-DF':'DF', 'TRE-GO':'GO', 'TRE-CE':'CE', 'TRE-MS':'MS',
       'TRE-PR':'PR', 'TRE-RN':'RN', 'TRE-AM':'AM', 'TRE-MT':'MT', 'TRE-TO':'TO', 'TRE-MA':'MA',
       'TRE-PB':'PB', 'TRE-PA':'PA', 'TRE-SE':'SE', 'TRE-PI':'PI', 'TRE-AP':'AP', 'TRE-RO':'RO',
       'TRE-RR':'RR', 'TRE/SC':'SC', 'TRE - SC':'SC','TRE-SC':'SC', 'TRE-AC':'AC'})

pesquisas['orgao_registro'] = pesquisas['orgao_registro'].map({'Sem dados':'Sem dados', 'TSE':'TSE', 'TRE':'TRE', 
        'TRE-SP':'TRE', 'TRE-AL':'TRE', 'TRE-PE':'TRE','TRE/MT':'TRE','TRE/RN':'TRE','TRE/SC':'TRE','TRE/MS':'TRE',
       '40ª Zona Eleitoral de Betim':'Zona Eleitoral', 'TRE-MG':'TRE', 'TRE-RJ':'TRE', 'TRE-ES':'TRE',
       'TRE-RS':'TRE', 'TRE-BA':'TRE', 'TRE-DF':'TRE', 'TRE-GO':'TRE', 'TRE-CE':'TRE', 'TRE-MS':'TRE',
       'TRE-PR':'TRE', 'TRE-RN':'TRE', 'TRE-AM':'TRE', 'TRE-MT':'TRE', 'TRE-TO':'TRE', 'TRE-MA':'TRE',
       'TRE-PB':'TRE', 'TRE-PA':'TRE', 'TRE-SE':'TRE', 'TRE-PI':'TRE', 'TRE-AP':'TRE', 'TRE-RO':'TRE',
       'TRE-RR':'TRE', 'TRE/SC':'TRE', 'TRE - SC':'TRE', 'TRE-AC':'TRE','TRE-SC':'TRE'})

# %%
# Pct Votos Totais/Validos
resultados['pct_votos_validos'] = resultados['votos']/resultados['votos_validos']
resultados['pct_votos_totais'] = resultados['votos']/resultados['total_votos']

# %%
# Dia da Eleição (Ano e turno)

pesquisas['data_eleicao'] = np.nan

# 2006
index = pesquisas[(pesquisas['ano']==2006)&(pesquisas['turno']==1)].index
pesquisas.loc[index,'data_eleicao'] = pd.to_datetime('01/10/2006')
index = pesquisas[(pesquisas['ano']==2006)&(pesquisas['turno']==2)].index
pesquisas.loc[index,'data_eleicao'] = pd.to_datetime('29/10/2006')

# 2010
index = pesquisas[(pesquisas['ano']==2010)&(pesquisas['turno']==1)].index
pesquisas.loc[index,'data_eleicao'] = pd.to_datetime('03/10/2010')
index = pesquisas[(pesquisas['ano']==2010)&(pesquisas['turno']==2)].index
pesquisas.loc[index,'data_eleicao'] = pd.to_datetime('31/10/2010')

# 2014
index = pesquisas[(pesquisas['ano']==2014)&(pesquisas['turno']==1)].index
pesquisas.loc[index,'data_eleicao'] = pd.to_datetime('05/10/2014')
index = pesquisas[(pesquisas['ano']==2014)&(pesquisas['turno']==2)].index
pesquisas.loc[index,'data_eleicao'] = pd.to_datetime('26/10/2014')

# 2018
index = pesquisas[(pesquisas['ano']==2018)&(pesquisas['turno']==1)].index
pesquisas.loc[index,'data_eleicao'] = pd.to_datetime('07/10/2018')
index = pesquisas[(pesquisas['ano']==2018)&(pesquisas['turno']==2)].index
pesquisas.loc[index,'data_eleicao'] = pd.to_datetime('28/10/2018')

# 2022
index = pesquisas[(pesquisas['ano']==2022)&(pesquisas['turno']==1)].index
pesquisas.loc[index,'data_eleicao'] = pd.to_datetime('02/10/2022')
index = pesquisas[(pesquisas['ano']==2022)&(pesquisas['turno']==2)].index
pesquisas.loc[index,'data_eleicao'] = pd.to_datetime('30/10/2022')

# %%
# Dias para a eleição
pesquisas['timedelta_eleicao'] = (pesquisas['data'] - pesquisas['data_eleicao']).dt.days

# %%
# Meses desde o último censo
pesquisas['timedelta_censo'] = (pesquisas['data']-(pesquisas['data'].dt.year).map({2006:pd.to_datetime('01/12/2000'),2010:pd.to_datetime('01/12/2000'),2014:pd.to_datetime('01/12/2010'),2018:pd.to_datetime('01/12/2010'),2022:pd.to_datetime('01/12/2010')})).dt.days/30

# %% [markdown]
# # 4.0 Final Dataset

# %% [markdown]
# ## 4.1 Left Join

# %%
resultados['join_aux'] = resultados['id_poder_360'].astype('str')+resultados['ano'].astype('str')+resultados['turno'].astype('str')
pesquisas['join_aux'] = pesquisas['id_candidato_poder360'].astype('str')+pesquisas['data'].dt.year.astype('str')+pesquisas['turno'].astype('str')
dados = pd.merge(pesquisas,resultados[['pct_votos_validos','pct_votos_totais','join_aux','local_que_concorreu']],on='join_aux',how='left')
dados.drop('join_aux',1,inplace=True)

# %% [markdown]
# ## 4.2 Drop NaN Results Candidates

# %%
dados = dados[~dados['pct_votos_validos'].isna()]

# %% [markdown]
# ## 4.3 Continue Feature Engineering

# %%
# Qtd de candidatos no cenario que não participaram efetivamente do pleito
aux = pesquisas.groupby('id_cenario').count()['id_candidato_poder360'].reset_index().rename(columns={'id_candidato_poder360':'qtd_candidatos'})
aux2 = dados.groupby('id_cenario').count()['id_candidato_poder360'].reset_index().rename(columns={'id_candidato_poder360':'qtd_candidatos_participaram'})
df_aux = pd.merge(aux,aux2,on='id_cenario',how='inner')
dados = pd.merge(dados,df_aux,on='id_cenario',how='left')

# %%
# % Relativo dos que efetiv. concorreram
dados['pct_participacao_candidatos'] = dados['qtd_candidatos_participaram']/dados['qtd_candidatos']

# %%
# % Total da Pesquisa, % dos que participaram, % dos que não participaram
aux = pesquisas.groupby('id_cenario').sum()['percentual'].reset_index().rename(columns={'percentual':'cum_cenario_pct'})
aux2 = dados.groupby('id_cenario').sum()['percentual'].reset_index().rename(columns={'percentual':'cum_cenario_pct_participaram'})
df_aux = pd.merge(aux,aux2,on='id_cenario',how='inner')
df_aux['cum_cenario_pct_nao_participaram'] = df_aux['cum_cenario_pct']-df_aux['cum_cenario_pct_participaram']
dados = pd.merge(dados,df_aux,on='id_cenario',how='left')

# %% [markdown]
# ## 4.4 Remove 2 Turno Não Efetivado

# %%
# Remove cenários 2 turno que só tem um candidato (Ex: ciro e lula em 2022, só lula foi pro 2 turno, então dropar esse cenário!)
cenarios2turno = dados[dados['turno']==2]['id_cenario'].unique()
lst = []
for cenario in cenarios2turno:
    if dados[dados['id_cenario']==cenario].shape[0] == 1:
        lst.append(cenario)
dados = dados[~dados['id_cenario'].isin(lst)]

# %% [markdown]
# ## 4.5 Erro da Pesquisa

# %%
# Real - Predito

dados.reset_index(drop=True,inplace=True)

dados['real'] = np.nan
for c in range(dados.shape[0]):
    if dados.loc[c,'tipo_voto']=='votos totais':
        dados.loc[c,'real']=dados.loc[c,'pct_votos_totais']
    elif dados.loc[c,'tipo_voto']=='votos válidos':
        dados.loc[c,'real']=dados.loc[c,'pct_votos_validos']
dados['real'] = dados['real']*100
dados['erro'] = dados['real'] - dados['percentual']

dados.drop(['pct_votos_validos','pct_votos_totais','real'],1,inplace=True)

# %%
dados
# Out:
#        id_pesquisa   ano       cargo       data  instituto  \
# 0             8023  2006  presidente 2006-09-19  Datafolha
# 1             8023  2006  presidente 2006-09-19  Datafolha
# 2             8023  2006  presidente 2006-09-19  Datafolha
# 3             8023  2006  presidente 2006-09-19  Datafolha
# 4             8023  2006  presidente 2006-09-19  Datafolha
# ...            ...   ...         ...        ...        ...
# 14524         3875  2014  presidente 2014-10-15  Datafolha
# 14525         3487  2014  presidente 2014-10-25  Datafolha
# 14526         3487  2014  presidente 2014-10-25  Datafolha
# 14527         3488  2014  presidente 2014-10-25  Datafolha
# 14528         3488  2014  presidente 2014-10-25  Datafolha
#
#                       contratante orgao_registro  quantidade_entrevistas  \
# 0                       Sem dados      Sem dados                  1640.0
# 1                       Sem dados      Sem dados                  1640.0
# 2                       Sem dados      Sem dados                  1640.0
# 3                       Sem dados      Sem dados                  1640.0
# 4                       Sem dados      Sem dados                  1640.0
# ...                           ...            ...                     ...
# 14524  Folha de S/ Paulo/TV Globo            TSE                  9081.0
# 14525  Folha de S/ Paulo/TV Globo            TSE                 19318.0
# 14526  Folha de S/ Paulo/TV Globo            TSE                 19318.0
# 14527  Folha de S/ Paulo/TV Globo            TSE                 19318.0
# 14528  Folha de S/ Paulo/TV Globo            TSE                 19318.0
#
#        margem_mais  margem_menos        tipo  turno      tipo_voto  \
# 0              2.0           2.0  estimulada      1   votos totais
# 1              2.0           2.0  estimulada      1   votos totais
# 2              2.0           2.0  estimulada      1   votos totais
# 3              2.0           2.0  estimulada      1   votos totais
# 4              2.0           2.0  estimulada      1   votos totais
# ...            ...           ...         ...    ...            ...
# 14524          2.0           2.0  estimulada      2   votos totais
# 14525          2.0           2.0  estimulada      2   votos totais
# 14526          2.0           2.0  estimulada      2   votos totais
# 14527          2.0           2.0  estimulada      2  votos válidos
# 14528          2.0           2.0  estimulada      2  votos válidos
#
#        id_cenario                     descricao_cenario  \
# 0           20265            cenário único - estimulado
# 1           20265            cenário único - estimulado
# 2           20265            cenário único - estimulado
# 3           20265            cenário único - estimulado
# 4           20265            cenário único - estimulado
# ...           ...                                   ...
# 14524       10056                   Diversos candidatos
# 14525        8594                   Diversos candidatos
# 14526        8594                   Diversos candidatos
# 14527        8595  Diversos candidatos (votos válidos)
# 14528        8595  Diversos candidatos (votos válidos)
#
#        id_candidato_poder360 sigla_partido  condicao  percentual  \
# 0                        938           PSL         0         0.0
# 1                        327           PDT         0         2.0
# 2                        645          Psol         0         9.0
# 3                        806          PSDC         0         0.0
# 4                         97           PRP         0         0.0
# ...                      ...           ...       ...         ...
# 14524                    176          PSDB         0        50.0
# 14525                    176          PSDB         0        43.0
# 14526                    361            PT         0        47.0
# 14527                    176          PSDB         0        48.0
# 14528                    361            PT         0        52.0
#
#        local_registro         data_eleicao  timedelta_eleicao  \
# 0           Sem dados  2006-01-10 00:00:00                252
# 1           Sem dados  2006-01-10 00:00:00                252
# 2           Sem dados  2006-01-10 00:00:00                252
# 3           Sem dados  2006-01-10 00:00:00                252
# 4           Sem dados  2006-01-10 00:00:00                252
# ...               ...                  ...                ...
# 14524  Esfera Federal  2014-10-26 00:00:00                -11
# 14525  Esfera Federal  2014-10-26 00:00:00                 -1
# 14526  Esfera Federal  2014-10-26 00:00:00                 -1
# 14527  Esfera Federal  2014-10-26 00:00:00                 -1
# 14528  Esfera Federal  2014-10-26 00:00:00                 -1
#
#        timedelta_censo local_que_concorreu  qtd_candidatos  \
# 0            81.400000                  br               9
# 1            81.400000                  br               9
# 2            81.400000                  br               9
# 3            81.400000                  br               9
# 4            81.400000                  br               9
# ...                ...                 ...             ...
# 14524        57.900000                  br               2
# 14525        58.233333                  br               3
# 14526        58.233333                  br               3
# 14527        58.233333                  br               2
# 14528        58.233333                  br               2
#
#        qtd_candidatos_participaram  pct_participacao_candidatos  \
# 0                                7                     0.777778
# 1                                7                     0.777778
# 2                                7                     0.777778
# 3                                7                     0.777778
# 4                                7                     0.777778
# ...                            ...                          ...
# 14524                            2                     1.000000
# 14525                            2                     0.666667
# 14526                            2                     0.666667
# 14527                            2                     1.000000
# 14528                            2                     1.000000
#
#        cum_cenario_pct  cum_cenario_pct_participaram  \
# 0                 99.0                          90.0
# 1                 99.0                          90.0
# 2                 99.0                          90.0
# 3                 99.0                          90.0
# 4                 99.0                          90.0
# ...                ...                           ...
# 14524             85.0                          85.0
# 14525            100.0                          90.0
# 14526            100.0                          90.0
# 14527            100.0                         100.0
# 14528            100.0                         100.0
#
#        cum_cenario_pct_nao_participaram      erro
# 0                                   9.0  0.059210
# 1                                   9.0  0.422088
# 2                                   9.0 -2.726995
# 3                                   9.0  0.060383
# 4                                   9.0  0.120591
# ...                                 ...       ...
# 14524                               0.0 -4.704120
# 14525                              10.0  2.295880
# 14526                              10.0  1.366384
# 14527                               0.0  0.360864
# 14528                               0.0 -0.360864
#
# [14529 rows x 31 columns]

# %% [markdown]
# # 5.0 Data Preparation

# %% [markdown]
# ## 5.1 Train Test Split (Time Series Constraint)

# %%
train = dados[dados['ano']!=2022]
test = dados[dados['ano']==2022]

x_train,y_train = train.drop('erro',1),train['erro']
x_test,y_test = test.drop('erro',1),test['erro']

# %% [markdown]
# ## 5.2 Drop Datetime Variables

# %%
x_train.drop(['data_eleicao','data'],1,inplace=True)
x_test.drop(['data_eleicao','data'],1,inplace=True)

# %% [markdown]
# ## 5.3 Avoid data leakage and Overfitting

# %%
x_train.drop(['id_pesquisa','id_cenario'],1,inplace=True)
x_test.drop(['id_pesquisa','id_cenario'],1,inplace=True)

# %% [markdown]
# ## 5.3 Encoding

# %%
# fazer um encoding decente

# %%
te = TargetEncoder()
te.fit(x_train['instituto'],y_train)
x_train['instituto'] = te.transform(x_train['instituto'])
x_test['instituto'] = te.transform(x_test['instituto'])

te.fit(x_train['contratante'],y_train)
x_train['contratante'] = te.transform(x_train['contratante'])
x_test['contratante'] = te.transform(x_test['contratante'])

te.fit(x_train['orgao_registro'],y_train)
x_train['orgao_registro'] = te.transform(x_train['orgao_registro'])
x_test['orgao_registro'] = te.transform(x_test['orgao_registro'])

te.fit(x_train['tipo'],y_train)
x_train['tipo'] = te.transform(x_train['tipo'])
x_test['tipo'] = te.transform(x_test['tipo'])

te.fit(x_train['tipo_voto'],y_train)
x_train['tipo_voto'] = te.transform(x_train['tipo_voto'])
x_test['tipo_voto'] = te.transform(x_test['tipo_voto'])

te.fit(x_train['descricao_cenario'],y_train)
x_train['descricao_cenario'] = te.transform(x_train['descricao_cenario'])
x_test['descricao_cenario'] = te.transform(x_test['descricao_cenario'])

te.fit(x_train['sigla_partido'],y_train)
x_train['sigla_partido'] = te.transform(x_train['sigla_partido'])
x_test['sigla_partido'] = te.transform(x_test['sigla_partido'])

te.fit(x_train['local_registro'],y_train)
x_train['local_registro'] = te.transform(x_train['local_registro'])
x_test['local_registro'] = te.transform(x_test['local_registro'])

te.fit(x_train['cargo'],y_train)
x_train['cargo'] = te.transform(x_train['cargo'])
x_test['cargo'] = te.transform(x_test['cargo'])

te.fit(x_train['local_que_concorreu'],y_train)
x_train['local_que_concorreu'] = te.transform(x_train['local_que_concorreu'])
x_test['local_que_concorreu'] = te.transform(x_test['local_que_concorreu'])

# %% [markdown]
# ## 5.3 Reescaling

# %%
# fazer um reescaling decente

# %%
sc = StandardScaler()
sc.fit(x_train)
x_train = sc.transform(x_train)
x_test = sc.transform(x_test)

# %% [markdown]
# ## 5.4 Feature Selection

# %%
boruta = BorutaPy(RandomForestRegressor(n_jobs=-1),n_estimators='auto',verbose=2,random_state=101)
boruta.fit(np.array(x_train),np.array(y_train))
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	26
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	26
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	26
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	26
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	26
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	26
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	26
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	16
# Tentative: 	1
# Rejected: 	9
# Iteration: 	9 / 100
# Confirmed: 	16
# Tentative: 	1
# Rejected: 	9
# Iteration: 	10 / 100
# Confirmed: 	16
# Tentative: 	1
# Rejected: 	9
# Iteration: 	11 / 100
# Confirmed: 	16
# Tentative: 	1
# Rejected: 	9
# Iteration: 	12 / 100
# Confirmed: 	16
# Tentative: 	1
# Rejected: 	9
# Iteration: 	13 / 100
# Confirmed: 	16
# Tentative: 	0
# Rejected: 	10
#
#
# BorutaPy finished running.
#
# Iteration: 	14 / 100
# Confirmed: 	16
# Tentative: 	0
# Rejected: 	10
# BorutaPy(estimator=RandomForestRegressor(n_estimators=58, n_jobs=-1,
#                                          random_state=RandomState(MT19937) at 0x16119A840),
#          n_estimators='auto', random_state=RandomState(MT19937) at 0x16119A840,
#          verbose=2)

# %%
# Colunas escolhidas
dados.drop(['data_eleicao','data','erro','id_pesquisa','id_cenario'],1).columns[boruta.support_]
# Out:
# Index(['ano', 'contratante', 'tipo', 'turno', 'tipo_voto', 'descricao_cenario',
#        'id_candidato_poder360', 'sigla_partido', 'percentual',
#        'timedelta_eleicao', 'timedelta_censo', 'qtd_candidatos',
#        'qtd_candidatos_participaram', 'pct_participacao_candidatos',
#        'cum_cenario_pct_participaram', 'cum_cenario_pct_nao_participaram'],
#       dtype='object')

# %%
x_train = pd.DataFrame(x_train,columns=dados.drop(['data_eleicao','data','erro','id_pesquisa','id_cenario'],1).columns)
x_test = pd.DataFrame(x_test,columns=dados.drop(['data_eleicao','data','erro','id_pesquisa','id_cenario'],1).columns)
x_train = x_train.loc[:,boruta.support_]
x_test = x_test.loc[:,boruta.support_]

# %% [markdown]
# # 6.0 Model Selection and Evaluation

# %% [markdown]
# ## 6.1 Hould Out

# %%
def houldout(model):
    model.fit(x_train,y_train)
    y_pred = model.predict(x_test)
    y_true = y_test

    mae = mean_absolute_error(y_true,y_pred)
    rmse = np.sqrt(mean_squared_error(y_true,y_pred))
    print('MAE: {:.2f}\nRMSE: {:.2f}'.format(mae,rmse))

# %% [markdown]
# ### 6.1.1 Linear Regression

# %%
houldout(LinearRegression())
# Out:
# MAE: 13.09
# RMSE: 16.47

# %% [markdown]
# ### 6.1.2 RandomForest

# %%
houldout(RandomForestRegressor())
# Out:
# MAE: 3.20
# RMSE: 6.49

# %% [markdown]
# ### 6.1.3 XGBoost

# %%
houldout(XGBRegressor())
# Out:
# MAE: 5.92
# RMSE: 8.32

# %%
houldout(XGBRegressor())
# Out:
# MAE: 4.97
# RMSE: 6.40

# %% [markdown]
# ### 6.1.4 LGBM

# %%
houldout(LGBMRegressor())
# Out:
# MAE: 5.65
# RMSE: 9.13

# %%
houldout(LGBMRegressor())
# Out:
# MAE: 4.79
# RMSE: 7.32

# %% [markdown]
# ## Cross Validation

# %%
# fazer com a restrição da timeseries

# %% [markdown]
# # 7.0 Hyperparameter Finetuning

# %% [markdown]
# # 8.0 Error and Business Interpretation

# %%
# coletar dados segundo turno 2022 e ver as previsões!
